# %%
import numpy as np 
import pandas as pd
import functools
import warnings
import holidays

from datetime import datetime

# %%
df_meteo = pd.read_parquet('meteorologia.parquet')

# %%
df_meteo.head()
# Out:
#                time  temperature_2m  precipitation  rain  cloudcover  \
# 0  2022-01-01T00:00            18.8            1.1   1.1         100
# 1  2022-01-01T01:00            18.4            0.9   0.9         100
# 2  2022-01-01T02:00            18.1            0.5   0.5         100
# 3  2022-01-01T03:00            18.1            0.2   0.2         100
# 4  2022-01-01T04:00            18.2            0.2   0.2         100
#
#    cloudcover_low  cloudcover_mid  cloudcover_high  windspeed_10m  \
# 0              51              85              100            9.3
# 1              95              88               99            9.7
# 2              95              96               98            7.5
# 3              86              71               99            5.9
# 4              98              72               98            5.8
#
#    windspeed_100m        date   hour  elevation  weathercode IATA
# 0            18.6  2022-01-01  00:00       1057           63  BSB
# ...

# %%
df_meteo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87600 entries, 0 to 8759
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   time             87600 non-null  object
#  1   temperature_2m   87600 non-null  float64
#  2   precipitation    87600 non-null  float64
#  3   rain             87600 non-null  float64
#  4   cloudcover       87600 non-null  int64
#  5   cloudcover_low   87600 non-null  int64
#  6   cloudcover_mid   87600 non-null  int64
#  7   cloudcover_high  87600 non-null  int64
#  8   windspeed_10m    87600 non-null  float64
#  9   windspeed_100m   87600 non-null  float64
#  10  date             87600 non-null  object
#  11  hour             87600 non-null  object
#  12  elevation        87600 non-null  int64
#  13  weathercode      87600 non-null  int64
#  14  IATA             87600 non-null  object
# dtypes: float64(5), int64(6), object(4)
# memory usage: 10.7+ MB

# %%
df_meteo["hora"] = df_meteo["hour"].str[:2].astype(int)

# %%
df_meteo["data"] = pd.to_datetime(df_meteo['date'], errors='coerce').dt.strftime("%d/%m/%Y")

# %%
df_meteo.head()
# Out:
#                time  temperature_2m  precipitation  rain  cloudcover  \
# 0  2022-01-01T00:00            18.8            1.1   1.1         100
# 1  2022-01-01T01:00            18.4            0.9   0.9         100
# 2  2022-01-01T02:00            18.1            0.5   0.5         100
# 3  2022-01-01T03:00            18.1            0.2   0.2         100
# 4  2022-01-01T04:00            18.2            0.2   0.2         100
#
#    cloudcover_low  cloudcover_mid  cloudcover_high  windspeed_10m  \
# 0              51              85              100            9.3
# 1              95              88               99            9.7
# 2              95              96               98            7.5
# 3              86              71               99            5.9
# 4              98              72               98            5.8
#
#    windspeed_100m        date   hour  elevation  weathercode IATA  hora  \
# 0            18.6  2022-01-01  00:00       1057           63  BSB     0
# ...

# %%
df_meteo.to_parquet('info_meteorologia.parquet')
